# %%
from datetime import datetime
datetime(year=2021, month=7, day=4)
# Out:
# datetime.datetime(2021, 7, 4, 0, 0)

# %%
from dateutil import parser
date = parser.parse('4th of July, 2021')
date
# Out:
# datetime.datetime(2021, 7, 4, 0, 0)

# %%
date.strftime('%A')
# Out:
# 'Sunday'

# %%
import numpy as np
date = np.array('2021-07-04', dtype=np.datetime64)
date
# Out:
# array('2021-07-04', dtype='datetime64[D]')

# %%
date + np.arange(12)
# Out:
# array(['2021-07-04', '2021-07-05', '2021-07-06', '2021-07-07',
#        '2021-07-08', '2021-07-09', '2021-07-10', '2021-07-11',
#        '2021-07-12', '2021-07-13', '2021-07-14', '2021-07-15'],
#       dtype='datetime64[D]')

# %%
np.datetime64('2021-07-04')
# Out:
# np.datetime64('2021-07-04')

# %%
np.datetime64('2021-07-04 12:00')
# Out:
# np.datetime64('2021-07-04T12:00')

# %%
np.datetime64('2021-07-04 12:59:59.50', 'ns')
# Out:
# np.datetime64('2021-07-04T12:59:59.500000000')

# %%
import pandas as pd
date  = pd.to_datetime("4th of July, 2021")
date
# Out:
# Timestamp('2021-07-04 00:00:00')

# %%
date.strftime('%A')
# Out:
# 'Sunday'

# %%
date + pd.to_timedelta(np.arange(12), 'D')
# Out:
# DatetimeIndex(['2021-07-04', '2021-07-05', '2021-07-06', '2021-07-07',
#                '2021-07-08', '2021-07-09', '2021-07-10', '2021-07-11',
#                '2021-07-12', '2021-07-13', '2021-07-14', '2021-07-15'],
#               dtype='datetime64[ns]', freq=None)

# %%
index = pd.DatetimeIndex(['2020-07-04', '2020-08-04',
                          '2021-07-04', '2021-08-04'])
data = pd.Series([0, 1, 2, 3], index=index)
data
# Out:
# 2020-07-04    0
# 2020-08-04    1
# 2021-07-04    2
# 2021-08-04    3
# dtype: int64

# %%
data['2020-07-04': '2021-07-04']
# Out:
# 2020-07-04    0
# 2020-08-04    1
# 2021-07-04    2
# dtype: int64

# %%
data['2021']
# Out:
# 2021-07-04    2
# 2021-08-04    3
# dtype: int64

# %%
dates = pd.to_datetime([datetime(2021, 7, 3), '4th of July, 2021',
                        '2021-Jul-6', '07-07-2021', '20210708'])
dates
# Out:
# DatetimeIndex(['2021-07-03', '2021-07-04', '2021-07-06', '2021-07-07',
#                '2021-07-08'],
#               dtype='datetime64[ns]', freq=None)

# %%
from pandas import PeriodIndex

dates.to_period('D')
PeriodIndex(['2021-07-03', '2021-07-04', '2021-07-06', '2021-07-07',
            '2021-07-08'],
            dtype='period[D]')

dates - dates[0]
# Out:
# TimedeltaIndex(['0 days', '1 days', '3 days', '4 days', '5 days'], dtype='timedelta64[ns]', freq=None)

# %%
pd.date_range('2015-07-03', '2015-07-10')
# Out:
# DatetimeIndex(['2015-07-03', '2015-07-04', '2015-07-05', '2015-07-06',
#                '2015-07-07', '2015-07-08', '2015-07-09', '2015-07-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range('2015-07-03', periods=8)
# Out:
# DatetimeIndex(['2015-07-03', '2015-07-04', '2015-07-05', '2015-07-06',
#                '2015-07-07', '2015-07-08', '2015-07-09', '2015-07-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range('2015-07-03', periods=8, freq='H')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_5044\3521404607.py:1: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   pd.date_range('2015-07-03', periods=8, freq='H')
# DatetimeIndex(['2015-07-03 00:00:00', '2015-07-03 01:00:00',
#                '2015-07-03 02:00:00', '2015-07-03 03:00:00',
#                '2015-07-03 04:00:00', '2015-07-03 05:00:00',
#                '2015-07-03 06:00:00', '2015-07-03 07:00:00'],
#               dtype='datetime64[ns]', freq='h')

# %%
pd.period_range('2015-07', periods=8, freq='M')
# Out:
# PeriodIndex(['2015-07', '2015-08', '2015-09', '2015-10', '2015-11', '2015-12',
#              '2016-01', '2016-02'],
#             dtype='period[M]')

# %%
pd.timedelta_range(0, periods=6, freq='H')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_5044\1860625161.py:1: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   pd.timedelta_range(0, periods=6, freq='H')
# TimedeltaIndex(['0 days 00:00:00', '0 days 01:00:00', '0 days 02:00:00',
#                 '0 days 03:00:00', '0 days 04:00:00', '0 days 05:00:00'],
#                dtype='timedelta64[ns]', freq='h')

# %%
pd.timedelta_range(0, periods=6, freq="2H30T")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_5044\22847273.py:1: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   pd.timedelta_range(0, periods=6, freq="2H30T")
# C:\Users\HP\AppData\Local\Temp\ipykernel_5044\22847273.py:1: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   pd.timedelta_range(0, periods=6, freq="2H30T")
# TimedeltaIndex(['0 days 00:00:00', '0 days 02:30:00', '0 days 05:00:00',
#                 '0 days 07:30:00', '0 days 10:00:00', '0 days 12:30:00'],
#                dtype='timedelta64[ns]', freq='150min')

# %%
from pandas.tseries.offsets import BDay
pd.date_range('2015-07-01', periods=6, freq=BDay())
# Out:
# DatetimeIndex(['2015-07-01', '2015-07-02', '2015-07-03', '2015-07-06',
#                '2015-07-07', '2015-07-08'],
#               dtype='datetime64[ns]', freq='B')

# %%
# !pip install -q yfinance

# %%
import yfinance as yf

sp500 = yf.download("^GSPC", start="2018-01-01", end="2022-01-02", progress=False)
sp500.head()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_5044\141075707.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   sp500 = yf.download("^GSPC", start="2018-01-01", end="2022-01-02", progress=False)
# Price             Close         High          Low         Open      Volume
# Ticker            ^GSPC        ^GSPC        ^GSPC        ^GSPC       ^GSPC
# Date
# 2018-01-02  2695.810059  2695.889893  2682.360107  2683.729980  3397430000
# 2018-01-03  2713.060059  2714.370117  2697.770020  2697.850098  3544030000
# 2018-01-04  2723.989990  2729.290039  2719.070068  2719.310059  3697340000
# 2018-01-05  2743.149902  2743.449951  2727.919922  2731.330078  3239280000
# 2018-01-08  2747.709961  2748.510010  2737.600098  2742.669922  3246160000

# %%
sp500 = sp500['Close']

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-whitegrid')
sp500.plot();

# %%
fig, ax = plt.subplots(figsize=(8,6))

sp500.plot(ax=ax, alpha=0.5, style="-")
sp500.resample("BA").mean().plot(ax=ax, style=":")
sp500.asfreq("BA").plot(ax=ax, style="--")
ax.legend(["input", "resample", "asfreq"], loc="upper left")
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_5044\3673156302.py:4: FutureWarning: 'BA' is deprecated and will be removed in a future version, please use 'BYE' instead.
#   sp500.resample("BA").mean().plot(ax=ax, style=":")
# C:\Users\HP\AppData\Local\Temp\ipykernel_5044\3673156302.py:5: FutureWarning: 'BA' is deprecated and will be removed in a future version, please use 'BYE' instead.
#   sp500.asfreq("BA").plot(ax=ax, style="--")

# %%
fig , ax = plt.subplots(2, sharex=True)
data = sp500.iloc[:20]

data.asfreq('D').plot(ax=ax[0], marker='o')

data.asfreq('D', method='bfill').plot(ax=ax[1], style='-o')
data.asfreq('D', method='ffill').plot(ax=ax[1], style='--o')
ax[1].legend(["back-fill", "forward-fill"]);

# %%
sp500 =sp500.asfreq('D', method='pad')

ROI = 100 * (sp500.shift(-365) -sp500) / sp500
ROI.plot()
plt.ylabel('% Return on Investment after 1 year');

# %%
rolling_mean   = sp500.rolling(window=365, center=True).mean()
rolling_median = sp500.rolling(window=365, center=True).median()

# %%
data = pd.DataFrame(index=sp500.index)
data["input"] = sp500
data["one-year rolling_mean"] = rolling_mean
data["one-year rolling_median"] = rolling_median

# %%
fig, ax = plt.subplots(figsize=(8,5))
data.plot(ax=ax, style={"input": "-",
                        "one-year rolling_mean": "--",
                        "one-year rolling_median": ":"})
ax.lines[0].set_alpha(0.3)
ax.set_ylabel("Close")
ax.set_title("S&P 500 Close with 1-Year Rolling Mean & Median")
ax.legend()
plt.show()

# %%
# url = ('https://raw.githubusercontent.com/jakevdp/bicycle-data/main/FremontBridge.csv')
# !curl -O {url}

# %%
data = pd.read_csv('data/FremontBridge.csv', index_col='Date', parse_dates=True)
data.head()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_5044\3227980017.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data = pd.read_csv('data/FremontBridge.csv', index_col='Date', parse_dates=True)
#                      Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 2019-11-01 00:00:00                  12.0                           7.0
# 2019-11-01 01:00:00                   7.0                           0.0
# 2019-11-01 02:00:00                   1.0                           0.0
# 2019-11-01 03:00:00                   6.0                           6.0
# 2019-11-01 04:00:00                   6.0                           5.0
#
#                      Fremont Bridge West Sidewalk
# Date
# 2019-11-01 00:00:00                           5.0
# 2019-11-01 01:00:00                           7.0
# 2019-11-01 02:00:00                           1.0
# 2019-11-01 03:00:00                           0.0
# 2019-11-01 04:00:00                           1.0

# %%
data.columns = ['Total', 'East', 'West']

# %%
data.dropna().describe()
# Out:
#                Total           East           West
# count  147255.000000  147255.000000  147255.000000
# mean      110.341462      50.077763      60.263699
# std       140.422051      64.634038      87.252147
# min         0.000000       0.000000       0.000000
# 25%        14.000000       6.000000       7.000000
# 50%        60.000000      28.000000      30.000000
# 75%       145.000000      68.000000      74.000000
# max      1097.000000     698.000000     850.000000

# %%
data.plot()
plt.ylabel('Hourly Bicycle Count');

# %%
weekly = data.resample('W').sum()
weekly.plot(style=['-', ':', '--'])
plt.ylabel('Weekly bicycle count');

# %%
daily = data.resample('D').sum()
daily.rolling(30, center=True).sum().plot(style=['-',':','--'])
plt.ylabel('mean hourly count');

# %%
daily.rolling(50, center=True,
              win_type='gaussian').sum(std=10).plot(style=['-',':','--']);

# %%
by_time = data.groupby(data.index.time).mean()
hourly_ticks = 4 * 60 * 60 * np.arange(6)
by_time.plot(xticks=hourly_ticks, style=['-',':','--']);

# %%
by_weekday = data.groupby(data.index.dayofweek).mean()
by_weekday.index = ['Mon', 'Tue', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun']
by_weekday.plot(style=['-',':','--'])
# Out:
# <Axes: >

# %%
weekend = np.where(data.index.weekday < 5, 'Weekday', 'Weekend')
by_time = data.groupby([weekend, data.index.time]).mean()

# %%
fig, ax = plt.subplots(1, 2, figsize=(14, 5))
by_time.loc['Weekday'].plot(ax=ax[0], title='Weekdays',
                           xticks=hourly_ticks, style=['-',':','--'])
by_time.loc['Weekend'].plot(ax=ax[1], title='Weekends',
                           xticks=hourly_ticks, style=['-',':','--']);
